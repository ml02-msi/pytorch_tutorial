# %% [markdown]
# ## CNN
# #### We will be applying basic CNN arch. to the fashion-mnist problem

# %% [markdown]
# ![image.png](attachment:f30268d4-d26e-433f-ab3a-9d8b2648b9d5.png)
